# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def min_max_normalize(lst):
    normalized = []
    
    for value in lst:
        normalized_num = (value - min(lst)) / (max(lst) - min(lst))
        normalized.append(normalized_num)
    
    return normalized

# %%
df = pd.read_csv("https://raw.githubusercontent.com/cjfghk5697/Japan_GDP_data_analysis/main/csv/gdp%2C%20consumer%2C%20growth.csv")
X= df["year"]
y = df["GDP"]
y=min_max_normalize(y)
plt.plot(X, y, 'o')
plt.ylabel("gdp")
line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X, y, 'o')
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)))
plt.show()
print("GDP:",line_fitter.coef_)
# Out:
# GDP: [0.01368556]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/cjfghk5697/Japan_GDP_data_analysis/main/csv/gdp%2C%20consumer%2C%20growth.csv")


y = df["GDP growth rate"]
y=min_max_normalize(y)

plt.plot(X, y, 'o')
plt.ylabel("GDP growth rate")
line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X, y, 'o')
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)))
plt.show()
print("GDP growth rate:",line_fitter.coef_)
# Out:
# GDP growth rate: [-0.00462866]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/cjfghk5697/Japan_GDP_data_analysis/main/csv/gdp%2C%20consumer%2C%20growth.csv")
X= df["year"]

y = df["consumer prices"]
y=min_max_normalize(y)

plt.plot(X, y, 'o')
plt.ylabel("consumer prices")
line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X, y, 'o')
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)))
plt.show()
print("consumer prices:",line_fitter.coef_)
# Out:
# consumer prices: [0.01221964]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/cjfghk5697/Japan_GDP_data_analysis/main/csv/income.csv")
X= df["year"]
y = df["income"]
y=min_max_normalize(y)

plt.plot(X, y, 'o')
plt.ylabel("income")
line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X, y, 'o')
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)))
plt.show()
print("income:",line_fitter.coef_)
# Out:
# income: [0.03571354]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/cjfghk5697/Japan_GDP_data_analysis/main/csv/export.csv")

y = df["export"]
y=min_max_normalize(y)

plt.plot(X, y, 'o')
plt.ylabel("export")
line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X, y, 'o')
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)))
plt.show()
print("export:",line_fitter.coef_)
# Out:
# export: [0.03296193]
